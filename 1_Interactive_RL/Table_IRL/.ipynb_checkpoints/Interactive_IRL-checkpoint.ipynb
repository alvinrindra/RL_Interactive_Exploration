# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov 20 12:43:35 2015

@author: cruz

"""
# Libraries Declaration
import numpy as np
import matplotlib.pyplot as plt
from classes.Variables import *
from classes.Scenario import Scenario
from classes.Agent import Agent
from classes.DataFiles import DataFiles

# %matplotlib inline

# %%
resultsFolder = 'results/'
files = DataFiles()
NUMBER_AGENTS = 30
NUMBER_EPISODES = 1000

# %%
def setupRewardsPlot():
    dataRL = np.genfromtxt(resultsFolder + 'rewardsRL.csv', delimiter=',')
    dataIRL = np.genfromtxt(resultsFolder + 'rewardsIRL.csv', delimiter=',')
    meansRL = np.mean(dataRL, axis=0)
    meansIRL = np.mean(dataIRL, axis=0)

    convolveSet = 50
    convolveRL = np.convolve(meansRL, np.ones(convolveSet) / convolveSet)
    convolveIRL = np.convolve(meansIRL, np.ones(convolveSet) / convolveSet)

    plt.rcParams['font.size'] = 16
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)

    plt.figure('Collected reward')
    plt.suptitle('Collected reward')

    plt.plot(meansIRL, label='Average reward IRL', linestyle='--', color='r')
    plt.plot(meansRL, label='Average reward RL', linestyle='--', color='y')

    plt.plot(convolveIRL, linestyle='-', color='0.2')
    plt.plot(convolveRL, linestyle='-', color='0.2')

    plt.legend(loc=4, prop={'size': 12})
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.grid()

    my_axis = plt.gca()
    # my_axis.set_ylim(Variables.punishment-0.8, Variables.reward)
    my_axis.set_xlim(convolveSet, len(meansRL))




# end of plotRewards method

# %%
def setupFailuresPlot():
    dataRL = np.genfromtxt(resultsFolder + 'failuresRL.csv', delimiter=',')
    dataIRL = np.genfromtxt(resultsFolder + 'failuresIRL.csv', delimiter=',')
    sumRL = np.sum(dataRL, axis=0)
    sumIRL = np.sum(dataIRL, axis=0)

    convolveSet = 50
    convolveRL = np.convolve(sumRL, np.ones(convolveSet) / convolveSet)
    convolveIRL = np.convolve(sumIRL, np.ones(convolveSet) / convolveSet)

    plt.rcParams['font.size'] = 16
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)

    plt.figure('Total amount of failures')
    plt.suptitle('Total amount of failures')

    plt.plot(sumIRL, label='Total amount of failures IRL: ', linestyle='--', color='r')
    plt.plot(sumRL, label='Total amount of failures RL: ', linestyle='--', color='y')

    plt.plot(convolveIRL, linestyle='-', color='0.2')
    plt.plot(convolveRL, linestyle='-', color='0.2')

    plt.legend(loc='center right', prop={'size': 12})
    plt.xlabel('Episodes')
    plt.ylabel('Failures')
    plt.grid()

    my_axis = plt.gca()
    # my_axis.set_ylim(Variables.punishment-0.8, Variables.reward)
    my_axis.set_xlim(convolveSet, len(sumRL))




# end of plotRewards method

# %%
def setupStepsPlot():
    dataRL = np.genfromtxt(resultsFolder + 'stepsRL.csv', delimiter=',')
    dataIRL = np.genfromtxt(resultsFolder + 'stepsIRL.csv', delimiter=',')

    meansRL = np.zeros(NUMBER_EPISODES)
    meansIRL = np.zeros(NUMBER_EPISODES)

    for i in range(0, NUMBER_EPISODES):
        episodestepsRL = dataRL[:, i]
        episodestepsIRL = dataIRL[:, i]
        meansRL[i] = np.mean(episodestepsRL[np.nonzero(episodestepsRL)])
        meansIRL[i] = np.mean(episodestepsIRL[np.nonzero(episodestepsIRL)])


    # meansRL = np.mean(dataRL, axis=0)
    # meansIRL = np.mean(dataIRL, axis=0)

    convolveSet = 50
    convolveRL = np.convolve(meansRL, np.ones(convolveSet) / convolveSet)
    convolveIRL = np.convolve(meansIRL, np.ones(convolveSet) / convolveSet)

    plt.rcParams['font.size'] = 16
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)

    plt.figure('Steps taken')
    plt.suptitle('Steps taken')

    plt.scatter(range(0, NUMBER_EPISODES), meansIRL, label='Average steps IRL', marker='.', color='r')
    plt.scatter(range(0, NUMBER_EPISODES), meansRL, label='Average steps RL', marker='.', color='y')


    # plt.plot(meansIRL, label='Average steps IRL', linestyle='--', color='r')
    # plt.plot(meansRL, label='Average steps RL', linestyle='--', color='y')
    # plt.plot(convolveIRL, linestyle='-', color='0.2')
    # plt.plot(convolveRL, linestyle='-', color='0.2')

    plt.legend(loc='upper center', prop={'size': 12})
    plt.xlabel('Episodes')
    plt.ylabel('Steps')
    plt.grid()

    my_axis = plt.gca()
    # my_axis.set_ylim(Variables.punishment-0.8, Variables.reward)
    my_axis.set_xlim(convolveSet, len(meansRL))




# end of plotSteps method

# %%
# Feedback parameter meaning differs depending on feedback strategy.
# For random advising: advice probability in every state
# For early advising, importance advising and mistake correcting: Advice budget per episode
def trainAgent(tries, episodes, scenario, teacherAgent=None, feedbackStrategy=0, feedbackParameter=0.0):
    if teacherAgent == None:
        filenameSteps = resultsFolder + 'stepsRL.csv'
        filenameRewards = resultsFolder + 'rewardsRL.csv'
        filenameFailures = resultsFolder + 'failuresRL.csv'
    else:
        filenameSteps = resultsFolder + 'stepsIRL.csv'
        filenameRewards = resultsFolder + 'rewardsIRL.csv'
        filenameFailures = resultsFolder + 'failuresIRL.csv'

    files.createFile(filenameSteps)
    files.createFile(filenameRewards)
    files.createFile(filenameFailures)

    for i in range(tries):
        print('Training agent number: ' + str(i + 1))
        agent = Agent(scenario)
        [steps, rewards, failures] = agent.train(episodes, teacherAgent, feedbackStrategy, feedbackParameter)

        files.addToFile(filenameSteps, steps)
        files.addFloatToFile(filenameRewards, rewards)
        files.addToFile(filenameFailures, failures)
    # endfor

    return agent


# end trainAgent method

# %%
if __name__ == "__main__":
    print("Interactive RL for cleaning a table is running ... ")
    tries = NUMBER_AGENTS
    episodes = NUMBER_EPISODES

    scenario = Scenario()

    # Training with autonomous RL
    print('RL is now training the teacher agent with autonomous RL')
    teacherAgent = trainAgent(tries, episodes, scenario)

    # Training with interactive RL

    # feedbackParameter = 0.3
    # feedbackStrategy = feedbackstrategy_random;
    #
    # feedbackParameter = 3
    # feedbackStrategy = feedbackstrategy_early;
    #
    # feedbackParameter = 4
    # feedbackStrategy = feedbackstrategy_importance;
    #
    feedbackParameter = 3
    feedbackStrategy = feedbackstrategy_correction;

    print('IRL is now training the learner agent with interactive RL')
    learnerAgent = trainAgent(tries, episodes, scenario, teacherAgent, feedbackStrategy, feedbackParameter)
    setupStepsPlot()
    setupRewardsPlot()
    setupFailuresPlot()
    plt.show()

print("The end")  # end of main method
# Out:
# Interactive RL for cleaning a table is running ...
# RL is now training the teacher agent with autonomous RL
# Training agent number: 1
# Total feedback amount in all episodes:0
# Total amount of failures869
# Total amount of successes131
# Training agent number: 2
# Total feedback amount in all episodes:0
# Total amount of failures864
# Total amount of successes136
# Training agent number: 3
# Total feedback amount in all episodes:0
# Total amount of failures971
# Total amount of successes29
# Training agent number: 4
# Total feedback amount in all episodes:0
# Total amount of failures937
# Total amount of successes63
# Training agent number: 5
# Total feedback amount in all episodes:0
# Total amount of failures905
# Total amount of successes95
# Training agent number: 6
# Total feedback amount in all episodes:0
# Total amount of failures922
# Total amount of successes78
# Training agent number: 7
# Total feedback amount in all episodes:0
# Total amount of failures879
# Total amount of successes121
# Training agent number: 8
# Total feedback amount in all episodes:0
# Total amount of failures838
# Total amount of successes162
# Training agent number: 9
# Total feedback amount in all episodes:0
# Total amount of failures902
# Total amount of successes98
# Training agent number: 10
# Total feedback amount in all episodes:0
# Total amount of failures899
# Total amount of successes101
# Training agent number: 11
# Total feedback amount in all episodes:0
# Total amount of failures908
# Total amount of successes92
# Training agent number: 12
# Total feedback amount in all episodes:0
# Total amount of failures903
# Total amount of successes97
# Training agent number: 13
# Total feedback amount in all episodes:0
# Total amount of failures881
# Total amount of successes119
# Training agent number: 14
# Total feedback amount in all episodes:0
# Total amount of failures900
# Total amount of successes100
# Training agent number: 15
# Total feedback amount in all episodes:0
# Total amount of failures881
# Total amount of successes119
# Training agent number: 16
# Total feedback amount in all episodes:0
# Total amount of failures887
# Total amount of successes113
# Training agent number: 17
# Total feedback amount in all episodes:0
# Total amount of failures903
# Total amount of successes97
# Training agent number: 18
# Total feedback amount in all episodes:0
# Total amount of failures962
# Total amount of successes38
# Training agent number: 19
# Total feedback amount in all episodes:0
# Total amount of failures922
# Total amount of successes78
# Training agent number: 20
# Total feedback amount in all episodes:0
# Total amount of failures832
# Total amount of successes168
# Training agent number: 21
# Total feedback amount in all episodes:0
# Total amount of failures914
# Total amount of successes86
# Training agent number: 22
# Total feedback amount in all episodes:0
# Total amount of failures845
# Total amount of successes155
# Training agent number: 23
# Total feedback amount in all episodes:0
# Total amount of failures811
# Total amount of successes189
# Training agent number: 24
# Total feedback amount in all episodes:0
# Total amount of failures872
# Total amount of successes128
# Training agent number: 25
# Total feedback amount in all episodes:0
# Total amount of failures932
# Total amount of successes68
# Training agent number: 26
# Total feedback amount in all episodes:0
# Total amount of failures942
# Total amount of successes58
# Training agent number: 27
# Total feedback amount in all episodes:0
# Total amount of failures916
# Total amount of successes84
# Training agent number: 28
# Total feedback amount in all episodes:0
# Total amount of failures919
# Total amount of successes81
# Training agent number: 29
# Total feedback amount in all episodes:0
# Total amount of failures864
# Total amount of successes136
# Training agent number: 30
# Total feedback amount in all episodes:0
# Total amount of failures859
# Total amount of successes141
# IRL is now training the learner agent with interactive RL
# Training agent number: 1
# Total feedback amount in all episodes:2074
# Total amount of failures444
# Total amount of successes556
# Training agent number: 2
# Total feedback amount in all episodes:2181
# Total amount of failures502
# Total amount of successes498
# Training agent number: 3
# Total feedback amount in all episodes:1826
# Total amount of failures312
# Total amount of successes688
# Training agent number: 4
# Total feedback amount in all episodes:2209
# Total amount of failures527
# Total amount of successes473
# Training agent number: 5
# Total feedback amount in all episodes:1880
# Total amount of failures336
# Total amount of successes664
# Training agent number: 6
# Total feedback amount in all episodes:1913
# Total amount of failures333
# Total amount of successes667
# Training agent number: 7
# Total feedback amount in all episodes:2101
# Total amount of failures437
# Total amount of successes563
# Training agent number: 8
# Total feedback amount in all episodes:2305
# Total amount of failures542
# Total amount of successes458
# Training agent number: 9
# Total feedback amount in all episodes:1838
# Total amount of failures352
# Total amount of successes648
# Training agent number: 10
# Total feedback amount in all episodes:2086
# Total amount of failures470
# Total amount of successes530
# Training agent number: 11
# Total feedback amount in all episodes:1953
# Total amount of failures383
# Total amount of successes617
# Training agent number: 12
# Total feedback amount in all episodes:1971
# Total amount of failures362
# Total amount of successes638
# Training agent number: 13
# Total feedback amount in all episodes:1931
# Total amount of failures382
# Total amount of successes618
# Training agent number: 14
# Total feedback amount in all episodes:1845
# Total amount of failures326
# Total amount of successes674
# Training agent number: 15
# Total feedback amount in all episodes:1720
# Total amount of failures216
# Total amount of successes784
# Training agent number: 16
# Total feedback amount in all episodes:2316
# Total amount of failures594
# Total amount of successes406
# Training agent number: 17
# Total feedback amount in all episodes:1783
# Total amount of failures270
# Total amount of successes730
# Training agent number: 18
# Total feedback amount in all episodes:1901
# Total amount of failures366
# Total amount of successes634
# Training agent number: 19
# Total feedback amount in all episodes:2036
# Total amount of failures445
# Total amount of successes555
# Training agent number: 20
# Total feedback amount in all episodes:2069
# Total amount of failures478
# Total amount of successes522
# Training agent number: 21
# Total feedback amount in all episodes:1813
# Total amount of failures276
# Total amount of successes724
# Training agent number: 22
# Total feedback amount in all episodes:1997
# Total amount of failures400
# Total amount of successes600
# Training agent number: 23
# Total feedback amount in all episodes:1754
# Total amount of failures262
# Total amount of successes738
# Training agent number: 24
# Total feedback amount in all episodes:1884
# Total amount of failures349
# Total amount of successes651
# Training agent number: 25
# Total feedback amount in all episodes:1992
# Total amount of failures400
# Total amount of successes600
# Training agent number: 26
# Total feedback amount in all episodes:2124
# Total amount of failures471
# Total amount of successes529
# Training agent number: 27
# Total feedback amount in all episodes:1805
# Total amount of failures309
# Total amount of successes691
# Training agent number: 28
# Total feedback amount in all episodes:1844
# Total amount of failures307
# Total amount of successes693
# Training agent number: 29
# Total feedback amount in all episodes:1960
# Total amount of failures386
# Total amount of successes614
# Training agent number: 30
# Total feedback amount in all episodes:2119
# Total amount of failures482
# Total amount of successes518
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# The end

# %%
??
# Out:
# Object `` not found.

# %%
matplotlib??
